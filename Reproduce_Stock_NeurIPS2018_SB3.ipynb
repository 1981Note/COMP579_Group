# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/1-Introduction/Stock_NeurIPS2018_SB3.py">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading
#
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Task Description](#0)
# * [2. Install Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. A List of Python Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download and Preprocess Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5. Build Market Environment in OpenAI Gym-style](#4)
#     * [5.1. Data Split](#4.1)
#     * [5.3. Environment for Training](#4.2)
# * [6. Train DRL Agents](#5)
# * [7. Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Task Discription

# %% [markdown]
# We train a DRL agent for stock trading. This task is modeled as a Markov Decision Process (MDP), and the objective function is maximizing (expected) cumulative return.
#
# We specify the state-action-reward as follows:
#
# * **State s**: The state space represents an agent's perception of the market environment. Just like a human trader analyzing various information, here our agent passively observes many features and learns by interacting with the market environment (usually by replaying historical data).
#
# * **Action a**: The action space includes allowed actions that an agent can take at each state. For example, a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying. When an action operates multiple shares, a ∈{−k, ..., −1, 0, 1, ..., k}, e.g.. "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * **Reward function r(s, a, s′)**: Reward is an incentive for an agent to learn a better policy. For example, it can be the change of the portfolio value when taking a at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio values at state s′ and s, respectively
#
#
# **Market environment**: 30 consituent stocks of Dow Jones Industrial Average (DJIA) index. Accessed at the starting date of the testing period.
#
#
# The data for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Install Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install packages

# %%
## install required packages
# !pip install swig
# !pip install wrds
# !pip install pyportfolioopt
## install finrl library
# !pip install -q condacolab
import condacolab
condacolab.install()
# !apt-get update -y -qq && apt-get install -y -qq cmake libopenmpi-dev python3-dev zlib1g-dev libgl1-mesa-glx swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. A list of Python packages
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3.common.logger import configure
from finrl.meta.data_processor import DataProcessor

from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from pprint import pprint

import sys
sys.path.append("../FinRL")

import itertools
# Out:
# /usr/local/lib/python3.10/site-packages/pyfolio/pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
from finrl import config
from finrl import config_tickers
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)
check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance provides stock data, financial news, financial reports, etc. Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** in FinRL-Meta to fetch data via Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()

# %%
TRAIN_START_DATE = '2009-01-01'
TRAIN_END_DATE = '2015-09-30'

TRADE_START_DATE = '2015-10-01'
TRADE_END_DATE = '2021-01-01'

# %%
df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = config_tickers.DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (88061, 8)

# %%
df.shape
# Out:
# (88061, 8)

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2009-01-02   3.067143   3.251429   3.041429   2.743888  746015200  AAPL
# 1  2009-01-02  58.590000  59.080002  57.750000  42.406391    6547900  AMGN
# 2  2009-01-02  18.570000  19.520000  18.400000  15.098143   10955700   AXP
# 3  2009-01-02  42.799999  45.560001  42.779999  33.941090    7010200    BA
# 4  2009-01-02  44.910000  46.980000  44.709999  30.950003    7117200   CAT
#
#    day
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4

# %% [markdown]
# # Part 4: Preprocess Data
# We need to check for missing data and do feature engineering to convert the data point into a state.
# * **Adding technical indicators**. In practical trading, various information needs to be taken into account, such as historical prices, current holding shares, technical indicators, etc. Here, we demonstrate two trend-following technical indicators: MACD and RSI.
# * **Adding turbulence index**. Risk-aversion reflects whether an investor prefers to protect the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the turbulence index that measures extreme fluctuation of asset price.

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
len(processed.tic.unique())
# Out:
# 29

# %% [markdown]
# <a id='4'></a>
# # Part 5. Build A Market Environment in OpenAI Gym-style
# The training process involves observing stock price change, taking an action and reward's calculation. By interacting with the market environment, the agent will eventually derive a trading strategy that may maximize (expected) rewards.
#
# Our market environment, based on OpenAI Gym, simulates stock markets with historical market data.

# %% [markdown]
# ## Data Split
# We split the data into training set and testing set as follows:
#
# Training data period: 2009-01-01 to 2020-07-01
#
# Trading data period: 2020-07-01 to 2021-10-31

# %%
train = data_split(processed, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 49213
# 38367

# %%
train.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'tic', 'day', 'macd',
#        'boll_ub', 'boll_lb', 'rsi_30', 'cci_30', 'dx_30', 'close_30_sma',
#        'close_60_sma', 'turbulence'],
#       dtype='object')

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %% [markdown]
# ## Environment for Training

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# <a id='5'></a>
# # Part 6: Train DRL Agents
# * The DRL algorithms are from **Stable Baselines 3**. Users are also encouraged to try **ElegantRL** and **Ray RLlib**.
# * FinRL includes fine-tuned standard DRL algorithms, such as DQN, DDPG, Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
agent = DRLAgent(env = env_train)

if_using_a2c = True
if_using_ddpg = True
if_using_ppo = True
if_using_td3 = True
if_using_sac = True

# %% [markdown]
# ### Agent Training: 5 algorithms (A2C, DDPG, PPO, TD3, SAC)

# %% [markdown]
# ### Agent 1: A2C

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")

if if_using_a2c:
  # set up logger
  tmp_path = RESULTS_DIR + '/a2c'
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device
# Logging to results/a2c

# %%
trained_a2c = agent.train_model(model=model_a2c,
                             tb_log_name='a2c',
                             total_timesteps=50000) if if_using_a2c else None
# Out:
# ----------------------------------------
# | time/                 |              |
# |    fps                | 124          |
# |    iterations         | 100          |
# |    time_elapsed       | 4            |
# |    total_timesteps    | 500          |
# | train/                |              |
# |    entropy_loss       | -41.4        |
# |    explained_variance | -0.724       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 99           |
# |    policy_loss        | -53.1        |
# |    reward             | -0.046486918 |
# |    std                | 1.01         |
# |    value_loss         | 2.23         |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 130        |
# |    iterations         | 200        |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | -0.0514    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | -13.9      |
# |    reward             | -1.3838851 |
# |    std                | 1.01       |
# |    value_loss         | 2.5        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 130       |
# |    iterations         | 300       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -270      |
# |    reward             | 6.488077  |
# |    std                | 1.01      |
# |    value_loss         | 51.2      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 132       |
# |    iterations         | 400       |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -0.0393   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 51.9      |
# |    reward             | 1.6480483 |
# |    std                | 1.01      |
# |    value_loss         | 2.35      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 134         |
# |    iterations         | 500         |
# |    time_elapsed       | 18          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -41.4       |
# |    explained_variance | 1.79e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | -44.3       |
# |    reward             | -0.49892738 |
# |    std                | 1.01        |
# |    value_loss         | 1.23        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 134        |
# |    iterations         | 600        |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | 1.73       |
# |    reward             | -0.4734528 |
# |    std                | 1.01       |
# |    value_loss         | 2.08       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 134        |
# |    iterations         | 700        |
# |    time_elapsed       | 26         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | -1.2       |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | 94.5       |
# |    reward             | 0.02834876 |
# |    std                | 1.01       |
# |    value_loss         | 7.08       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 134       |
# |    iterations         | 800       |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -152      |
# |    reward             | 1.7486433 |
# |    std                | 1.01      |
# |    value_loss         | 12.5      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 134      |
# |    iterations         | 900      |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -41.5    |
# |    explained_variance | 0.11     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -3.99    |
# |    reward             | 2.917363 |
# |    std                | 1.01     |
# |    value_loss         | 0.47     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 134        |
# |    iterations         | 1000       |
# |    time_elapsed       | 37         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | 300        |
# |    reward             | -0.9481747 |
# |    std                | 1.01       |
# |    value_loss         | 56         |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 134       |
# |    iterations         | 1100      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -174      |
# |    reward             | 0.3431171 |
# |    std                | 1.01      |
# |    value_loss         | 18.3      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 134       |
# |    iterations         | 1200      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -8.08     |
# |    reward             | 0.2396158 |
# |    std                | 1.01      |
# |    value_loss         | 4.91      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 134       |
# |    iterations         | 1300      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -41.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | -287      |
# |    reward             | 3.3581522 |
# |    std                | 1.02      |
# |    value_loss         | 60.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 135       |
# |    iterations         | 1400      |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0.0524    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -96.5     |
# |    reward             | 2.0083144 |
# |    std                | 1.02      |
# |    value_loss         | 6.4       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 135       |
# |    iterations         | 1500      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41.6     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 162       |
# |    reward             | 0.0668232 |
# |    std                | 1.02      |
# |    value_loss         | 20        |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 135        |
# |    iterations         | 1600       |
# |    time_elapsed       | 59         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | -287       |
# |    reward             | 0.47320485 |
# |    std                | 1.02       |
# |    value_loss         | 46.8       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 134         |
# |    iterations         | 1700        |
# |    time_elapsed       | 63          |
# |    total_timesteps    | 8500        |
# | train/                |             |
# |    entropy_loss       | -41.7       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1699        |
# |    policy_loss        | -6.12       |
# |    reward             | 0.042855784 |
# |    std                | 1.02        |
# |    value_loss         | 0.0598      |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 134         |
# |    iterations         | 1800        |
# |    time_elapsed       | 66          |
# |    total_timesteps    | 9000        |
# | train/                |             |
# |    entropy_loss       | -41.7       |
# |    explained_variance | -0.279      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1799        |
# |    policy_loss        | 39.3        |
# |    reward             | -0.13720442 |
# |    std                | 1.02        |
# |    value_loss         | 1           |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 134        |
# |    iterations         | 1900       |
# |    time_elapsed       | 70         |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | -90.5      |
# |    reward             | 0.32205367 |
# |    std                | 1.02       |
# |    value_loss         | 7.03       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 134       |
# |    iterations         | 2000      |
# |    time_elapsed       | 74        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -200      |
# |    reward             | -3.368142 |
# |    std                | 1.02      |
# |    value_loss         | 30        |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 134        |
# |    iterations         | 2100       |
# |    time_elapsed       | 78         |
# |    total_timesteps    | 10500      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2099       |
# |    policy_loss        | 35.5       |
# |    reward             | 0.12256327 |
# |    std                | 1.02       |
# |    value_loss         | 1.02       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 134       |
# |    iterations         | 2200      |
# |    time_elapsed       | 81        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | 63.2      |
# |    reward             | 0.8187473 |
# |    std                | 1.02      |
# |    value_loss         | 7.59      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 134       |
# |    iterations         | 2300      |
# |    time_elapsed       | 85        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | 110       |
# |    reward             | 1.6070634 |
# |    std                | 1.02      |
# |    value_loss         | 24.9      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 134        |
# |    iterations         | 2400       |
# |    time_elapsed       | 88         |
# |    total_timesteps    | 12000      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | -0.215     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2399       |
# |    policy_loss        | 10.2       |
# |    reward             | -0.3690461 |
# |    std                | 1.02       |
# |    value_loss         | 2.47       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 134       |
# |    iterations         | 2500      |
# |    time_elapsed       | 92        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | 44.7      |
# |    reward             | 1.9664207 |
# |    std                | 1.02      |
# |    value_loss         | 4.83      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 135      |
# |    iterations         | 2600     |
# |    time_elapsed       | 96       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -41.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 145      |
# |    reward             | 3.149942 |
# |    std                | 1.02     |
# |    value_loss         | 16.7     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 135       |
# |    iterations         | 2700      |
# |    time_elapsed       | 99        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | -264      |
# |    reward             | -3.719893 |
# |    std                | 1.02      |
# |    value_loss         | 45.1      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 135        |
# |    iterations         | 2800       |
# |    time_elapsed       | 103        |
# |    total_timesteps    | 14000      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2799       |
# |    policy_loss        | 81.4       |
# |    reward             | 0.44949058 |
# |    std                | 1.02       |
# |    value_loss         | 4.94       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 135         |
# |    iterations         | 2900        |
# |    time_elapsed       | 107         |
# |    total_timesteps    | 14500       |
# | train/                |             |
# |    entropy_loss       | -41.7       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2899        |
# |    policy_loss        | -0.607      |
# |    reward             | -0.19220383 |
# |    std                | 1.02        |
# |    value_loss         | 0.196       |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 135       |
# |    iterations         | 3000      |
# |    time_elapsed       | 110       |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | 0.0117    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | 88.3      |
# |    reward             | 1.2263696 |
# |    std                | 1.02      |
# |    value_loss         | 11.4      |
# -------------------------------------
# day: 1696, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 4056358.58
# total_reward: 3056358.58
# total_cost: 21709.28
# total_trades: 29224
# Sharpe: 1.268
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 135       |
# |    iterations         | 3100      |
# |    time_elapsed       | 114       |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | 29.8      |
# |    reward             | 0.5630452 |
# |    std                | 1.02      |
# |    value_loss         | 1.73      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 135        |
# |    iterations         | 3200       |
# |    time_elapsed       | 118        |
# |    total_timesteps    | 16000      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3199       |
# |    policy_loss        | 203        |
# |    reward             | 0.86072725 |
# |    std                | 1.02       |
# |    value_loss         | 25.8       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 135       |
# |    iterations         | 3300      |
# |    time_elapsed       | 121       |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | -0.00699  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | 110       |
# |    reward             | 1.2990429 |
# |    std                | 1.02      |
# |    value_loss         | 9.08      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 135       |
# |    iterations         | 3400      |
# |    time_elapsed       | 125       |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | 21.3      |
# |    reward             | -1.371447 |
# |    std                | 1.03      |
# |    value_loss         | 0.428     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 135       |
# |    iterations         | 3500      |
# |    time_elapsed       | 129       |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | 97.3      |
# |    reward             | 1.8223487 |
# |    std                | 1.03      |
# |    value_loss         | 7.82      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 135        |
# |    iterations         | 3600       |
# |    time_elapsed       | 133        |
# |    total_timesteps    | 18000      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3599       |
# |    policy_loss        | -18.3      |
# |    reward             | 0.07695898 |
# |    std                | 1.03       |
# |    value_loss         | 0.423      |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 135      |
# |    iterations         | 3700     |
# |    time_elapsed       | 136      |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -41.9    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 163      |
# |    reward             | 4.961297 |
# |    std                | 1.03     |
# |    value_loss         | 52.2     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 135        |
# |    iterations         | 3800       |
# |    time_elapsed       | 140        |
# |    total_timesteps    | 19000      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3799       |
# |    policy_loss        | 19         |
# |    reward             | -3.3717074 |
# |    std                | 1.03       |
# |    value_loss         | 0.551      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 135       |
# |    iterations         | 3900      |
# |    time_elapsed       | 144       |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | 142       |
# |    reward             | 1.3078055 |
# |    std                | 1.03      |
# |    value_loss         | 14.6      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 135       |
# |    iterations         | 4000      |
# |    time_elapsed       | 147       |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -42.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | -118      |
# |    reward             | 1.7913318 |
# |    std                | 1.03      |
# |    value_loss         | 9.42      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 135        |
# |    iterations         | 4100       |
# |    time_elapsed       | 151        |
# |    total_timesteps    | 20500      |
# | train/                |            |
# |    entropy_loss       | -42        |
# |    explained_variance | -0.218     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4099       |
# |    policy_loss        | 88.4       |
# |    reward             | 0.78122544 |
# |    std                | 1.03       |
# |    value_loss         | 5.08       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 135        |
# |    iterations         | 4200       |
# |    time_elapsed       | 154        |
# |    total_timesteps    | 21000      |
# | train/                |            |
# |    entropy_loss       | -42        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4199       |
# |    policy_loss        | 94.9       |
# |    reward             | 0.71501976 |
# |    std                | 1.03       |
# |    value_loss         | 9.15       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 135         |
# |    iterations         | 4300        |
# |    time_elapsed       | 158         |
# |    total_timesteps    | 21500       |
# | train/                |             |
# |    entropy_loss       | -42.1       |
# |    explained_variance | 0.0776      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4299        |
# |    policy_loss        | 34.3        |
# |    reward             | -0.58692867 |
# |    std                | 1.03        |
# |    value_loss         | 4.15        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 135        |
# |    iterations         | 4400       |
# |    time_elapsed       | 162        |
# |    total_timesteps    | 22000      |
# | train/                |            |
# |    entropy_loss       | -42.1      |
# |    explained_variance | -0.00127   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4399       |
# |    policy_loss        | 15         |
# |    reward             | -0.7712649 |
# |    std                | 1.04       |
# |    value_loss         | 4.11       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 135        |
# |    iterations         | 4500       |
# |    time_elapsed       | 165        |
# |    total_timesteps    | 22500      |
# | train/                |            |
# |    entropy_loss       | -42.2      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4499       |
# |    policy_loss        | -53.7      |
# |    reward             | -0.6508881 |
# |    std                | 1.04       |
# |    value_loss         | 2.47       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 135         |
# |    iterations         | 4600        |
# |    time_elapsed       | 169         |
# |    total_timesteps    | 23000       |
# | train/                |             |
# |    entropy_loss       | -42.2       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4599        |
# |    policy_loss        | 101         |
# |    reward             | -0.27528158 |
# |    std                | 1.04        |
# |    value_loss         | 13.8        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 135         |
# |    iterations         | 4700        |
# |    time_elapsed       | 173         |
# |    total_timesteps    | 23500       |
# | train/                |             |
# |    entropy_loss       | -42.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4699        |
# |    policy_loss        | 8.74        |
# |    reward             | -0.06521715 |
# |    std                | 1.04        |
# |    value_loss         | 0.883       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 135        |
# |    iterations         | 4800       |
# |    time_elapsed       | 176        |
# |    total_timesteps    | 24000      |
# | train/                |            |
# |    entropy_loss       | -42.2      |
# |    explained_variance | -0.0523    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4799       |
# |    policy_loss        | 16.7       |
# |    reward             | -1.9105974 |
# |    std                | 1.04       |
# |    value_loss         | 0.783      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 135        |
# |    iterations         | 4900       |
# |    time_elapsed       | 180        |
# |    total_timesteps    | 24500      |
# | train/                |            |
# |    entropy_loss       | -42.2      |
# |    explained_variance | 0.0174     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4899       |
# |    policy_loss        | 69.2       |
# |    reward             | -2.4473426 |
# |    std                | 1.04       |
# |    value_loss         | 11.1       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 135         |
# |    iterations         | 5000        |
# |    time_elapsed       | 184         |
# |    total_timesteps    | 25000       |
# | train/                |             |
# |    entropy_loss       | -42.3       |
# |    explained_variance | -0.0173     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4999        |
# |    policy_loss        | -113        |
# |    reward             | -0.43698075 |
# |    std                | 1.04        |
# |    value_loss         | 7.6         |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 135      |
# |    iterations         | 5100     |
# |    time_elapsed       | 187      |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -42.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -121     |
# |    reward             | 3.787343 |
# |    std                | 1.04     |
# |    value_loss         | 11.7     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 136       |
# |    iterations         | 5200      |
# |    time_elapsed       | 191       |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | -134      |
# |    reward             | 3.0276587 |
# |    std                | 1.04      |
# |    value_loss         | 11.5      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 136         |
# |    iterations         | 5300        |
# |    time_elapsed       | 194         |
# |    total_timesteps    | 26500       |
# | train/                |             |
# |    entropy_loss       | -42.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5299        |
# |    policy_loss        | -119        |
# |    reward             | -0.39826345 |
# |    std                | 1.04        |
# |    value_loss         | 8.17        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 136       |
# |    iterations         | 5400      |
# |    time_elapsed       | 198       |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | -0.000805 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | 88.8      |
# |    reward             | 1.752821  |
# |    std                | 1.04      |
# |    value_loss         | 4.82      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 136       |
# |    iterations         | 5500      |
# |    time_elapsed       | 201       |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | 0.191     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | -62.4     |
# |    reward             | 1.9176818 |
# |    std                | 1.04      |
# |    value_loss         | 6.21      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 136        |
# |    iterations         | 5600       |
# |    time_elapsed       | 205        |
# |    total_timesteps    | 28000      |
# | train/                |            |
# |    entropy_loss       | -42.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5599       |
# |    policy_loss        | -153       |
# |    reward             | -1.2140732 |
# |    std                | 1.04       |
# |    value_loss         | 14.7       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 136       |
# |    iterations         | 5700      |
# |    time_elapsed       | 209       |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | -135      |
# |    reward             | 2.1980677 |
# |    std                | 1.04      |
# |    value_loss         | 11.3      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 136         |
# |    iterations         | 5800        |
# |    time_elapsed       | 212         |
# |    total_timesteps    | 29000       |
# | train/                |             |
# |    entropy_loss       | -42.3       |
# |    explained_variance | 0.182       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5799        |
# |    policy_loss        | 90.1        |
# |    reward             | -0.13453746 |
# |    std                | 1.04        |
# |    value_loss         | 4.87        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 136         |
# |    iterations         | 5900        |
# |    time_elapsed       | 216         |
# |    total_timesteps    | 29500       |
# | train/                |             |
# |    entropy_loss       | -42.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5899        |
# |    policy_loss        | -300        |
# |    reward             | -0.29498944 |
# |    std                | 1.04        |
# |    value_loss         | 54.6        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 136        |
# |    iterations         | 6000       |
# |    time_elapsed       | 219        |
# |    total_timesteps    | 30000      |
# | train/                |            |
# |    entropy_loss       | -42.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5999       |
# |    policy_loss        | -128       |
# |    reward             | 0.15860218 |
# |    std                | 1.04       |
# |    value_loss         | 11.8       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 136        |
# |    iterations         | 6100       |
# |    time_elapsed       | 223        |
# |    total_timesteps    | 30500      |
# | train/                |            |
# |    entropy_loss       | -42.2      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6099       |
# |    policy_loss        | -50.1      |
# |    reward             | -1.0082605 |
# |    std                | 1.04       |
# |    value_loss         | 2.14       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 136        |
# |    iterations         | 6200       |
# |    time_elapsed       | 227        |
# |    total_timesteps    | 31000      |
# | train/                |            |
# |    entropy_loss       | -42.3      |
# |    explained_variance | 0.456      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6199       |
# |    policy_loss        | 3.55       |
# |    reward             | 0.09598795 |
# |    std                | 1.04       |
# |    value_loss         | 0.156      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 136       |
# |    iterations         | 6300      |
# |    time_elapsed       | 230       |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -42.2     |
# |    explained_variance | 3.52e-06  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | 15        |
# |    reward             | 2.2695603 |
# |    std                | 1.04      |
# |    value_loss         | 0.361     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 136        |
# |    iterations         | 6400       |
# |    time_elapsed       | 234        |
# |    total_timesteps    | 32000      |
# | train/                |            |
# |    entropy_loss       | -42.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6399       |
# |    policy_loss        | 34.9       |
# |    reward             | -3.6681306 |
# |    std                | 1.04       |
# |    value_loss         | 5.84       |
# --------------------------------------
# day: 1696, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 3051367.66
# total_reward: 2051367.66
# total_cost: 10606.15
# total_trades: 22116
# Sharpe: 1.049
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 136       |
# |    iterations         | 6500      |
# |    time_elapsed       | 238       |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6499      |
# |    policy_loss        | -22.9     |
# |    reward             | 1.6054997 |
# |    std                | 1.04      |
# |    value_loss         | 0.814     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 136         |
# |    iterations         | 6600        |
# |    time_elapsed       | 241         |
# |    total_timesteps    | 33000       |
# | train/                |             |
# |    entropy_loss       | -42.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6599        |
# |    policy_loss        | 113         |
# |    reward             | -0.35334584 |
# |    std                | 1.04        |
# |    value_loss         | 17          |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 136          |
# |    iterations         | 6700         |
# |    time_elapsed       | 245          |
# |    total_timesteps    | 33500        |
# | train/                |              |
# |    entropy_loss       | -42.3        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 6699         |
# |    policy_loss        | 121          |
# |    reward             | -0.071636446 |
# |    std                | 1.04         |
# |    value_loss         | 17.4         |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 136       |
# |    iterations         | 6800      |
# |    time_elapsed       | 248       |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | 114       |
# |    reward             | 3.0923858 |
# |    std                | 1.04      |
# |    value_loss         | 15.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 136       |
# |    iterations         | 6900      |
# |    time_elapsed       | 252       |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | 7.4e-05   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6899      |
# |    policy_loss        | -58       |
# |    reward             | 1.2499782 |
# |    std                | 1.04      |
# |    value_loss         | 5.34      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 136        |
# |    iterations         | 7000       |
# |    time_elapsed       | 256        |
# |    total_timesteps    | 35000      |
# | train/                |            |
# |    entropy_loss       | -42.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6999       |
# |    policy_loss        | 55.5       |
# |    reward             | -1.6190876 |
# |    std                | 1.05       |
# |    value_loss         | 2.61       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 136       |
# |    iterations         | 7100      |
# |    time_elapsed       | 259       |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | -386      |
# |    reward             | -4.799218 |
# |    std                | 1.05      |
# |    value_loss         | 95.2      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 136        |
# |    iterations         | 7200       |
# |    time_elapsed       | 263        |
# |    total_timesteps    | 36000      |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7199       |
# |    policy_loss        | -163       |
# |    reward             | -1.5420755 |
# |    std                | 1.05       |
# |    value_loss         | 16.4       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 136       |
# |    iterations         | 7300      |
# |    time_elapsed       | 266       |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -42.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | -86.7     |
# |    reward             | 4.8181767 |
# |    std                | 1.05      |
# |    value_loss         | 4.67      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 136        |
# |    iterations         | 7400       |
# |    time_elapsed       | 270        |
# |    total_timesteps    | 37000      |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7399       |
# |    policy_loss        | 44.4       |
# |    reward             | 0.93295485 |
# |    std                | 1.05       |
# |    value_loss         | 6.55       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 136         |
# |    iterations         | 7500        |
# |    time_elapsed       | 274         |
# |    total_timesteps    | 37500       |
# | train/                |             |
# |    entropy_loss       | -42.5       |
# |    explained_variance | 0.0163      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 7499        |
# |    policy_loss        | 137         |
# |    reward             | -0.68263274 |
# |    std                | 1.05        |
# |    value_loss         | 15.2        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 136       |
# |    iterations         | 7600      |
# |    time_elapsed       | 277       |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -42.5     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7599      |
# |    policy_loss        | 178       |
# |    reward             | 2.7726066 |
# |    std                | 1.05      |
# |    value_loss         | 36.3      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 136        |
# |    iterations         | 7700       |
# |    time_elapsed       | 281        |
# |    total_timesteps    | 38500      |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7699       |
# |    policy_loss        | -253       |
# |    reward             | -0.5879749 |
# |    std                | 1.05       |
# |    value_loss         | 42.1       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 136       |
# |    iterations         | 7800      |
# |    time_elapsed       | 284       |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -42.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7799      |
# |    policy_loss        | -6.96     |
# |    reward             | 5.4679136 |
# |    std                | 1.05      |
# |    value_loss         | 6.92      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 137        |
# |    iterations         | 7900       |
# |    time_elapsed       | 288        |
# |    total_timesteps    | 39500      |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7899       |
# |    policy_loss        | 85.7       |
# |    reward             | 0.21620482 |
# |    std                | 1.05       |
# |    value_loss         | 4.63       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 136       |
# |    iterations         | 8000      |
# |    time_elapsed       | 291       |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -42.6     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7999      |
# |    policy_loss        | -55.4     |
# |    reward             | -5.052958 |
# |    std                | 1.05      |
# |    value_loss         | 3.43      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 137        |
# |    iterations         | 8100       |
# |    time_elapsed       | 295        |
# |    total_timesteps    | 40500      |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8099       |
# |    policy_loss        | 321        |
# |    reward             | -0.3878094 |
# |    std                | 1.05       |
# |    value_loss         | 68.1       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 137      |
# |    iterations         | 8200     |
# |    time_elapsed       | 299      |
# |    total_timesteps    | 41000    |
# | train/                |          |
# |    entropy_loss       | -42.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8199     |
# |    policy_loss        | -220     |
# |    reward             | 2.508713 |
# |    std                | 1.06     |
# |    value_loss         | 33.5     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 137        |
# |    iterations         | 8300       |
# |    time_elapsed       | 302        |
# |    total_timesteps    | 41500      |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8299       |
# |    policy_loss        | -65.4      |
# |    reward             | -1.3584679 |
# |    std                | 1.06       |
# |    value_loss         | 3.23       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 137        |
# |    iterations         | 8400       |
# |    time_elapsed       | 306        |
# |    total_timesteps    | 42000      |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8399       |
# |    policy_loss        | 13         |
# |    reward             | -3.7731807 |
# |    std                | 1.05       |
# |    value_loss         | 4.97       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 137         |
# |    iterations         | 8500        |
# |    time_elapsed       | 310         |
# |    total_timesteps    | 42500       |
# | train/                |             |
# |    entropy_loss       | -42.6       |
# |    explained_variance | -0.38       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8499        |
# |    policy_loss        | 172         |
# |    reward             | -0.29523686 |
# |    std                | 1.05        |
# |    value_loss         | 31.8        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 137        |
# |    iterations         | 8600       |
# |    time_elapsed       | 313        |
# |    total_timesteps    | 43000      |
# | train/                |            |
# |    entropy_loss       | -42.7      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8599       |
# |    policy_loss        | -71.7      |
# |    reward             | 0.65000534 |
# |    std                | 1.06       |
# |    value_loss         | 3.16       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 137         |
# |    iterations         | 8700        |
# |    time_elapsed       | 317         |
# |    total_timesteps    | 43500       |
# | train/                |             |
# |    entropy_loss       | -42.7       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8699        |
# |    policy_loss        | 67.4        |
# |    reward             | -0.59793895 |
# |    std                | 1.06        |
# |    value_loss         | 12.1        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 137       |
# |    iterations         | 8800      |
# |    time_elapsed       | 320       |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -42.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | -81.7     |
# |    reward             | 3.3402946 |
# |    std                | 1.06      |
# |    value_loss         | 19.3      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 137        |
# |    iterations         | 8900       |
# |    time_elapsed       | 324        |
# |    total_timesteps    | 44500      |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8899       |
# |    policy_loss        | -154       |
# |    reward             | 0.55776525 |
# |    std                | 1.05       |
# |    value_loss         | 14.4       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 137       |
# |    iterations         | 9000      |
# |    time_elapsed       | 328       |
# |    total_timesteps    | 45000     |
# | train/                |           |
# |    entropy_loss       | -42.5     |
# |    explained_variance | -0.0013   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8999      |
# |    policy_loss        | 83.6      |
# |    reward             | 1.8744208 |
# |    std                | 1.05      |
# |    value_loss         | 9.61      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 137      |
# |    iterations         | 9100     |
# |    time_elapsed       | 331      |
# |    total_timesteps    | 45500    |
# | train/                |          |
# |    entropy_loss       | -42.5    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9099     |
# |    policy_loss        | -8.84    |
# |    reward             | 2.626678 |
# |    std                | 1.05     |
# |    value_loss         | 4.65     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 137        |
# |    iterations         | 9200       |
# |    time_elapsed       | 335        |
# |    total_timesteps    | 46000      |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | -0.317     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9199       |
# |    policy_loss        | -1.02      |
# |    reward             | 0.42875108 |
# |    std                | 1.06       |
# |    value_loss         | 0.843      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 137       |
# |    iterations         | 9300      |
# |    time_elapsed       | 338       |
# |    total_timesteps    | 46500     |
# | train/                |           |
# |    entropy_loss       | -42.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9299      |
# |    policy_loss        | -21.7     |
# |    reward             | 3.1942494 |
# |    std                | 1.06      |
# |    value_loss         | 6.19      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 137        |
# |    iterations         | 9400       |
# |    time_elapsed       | 342        |
# |    total_timesteps    | 47000      |
# | train/                |            |
# |    entropy_loss       | -42.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9399       |
# |    policy_loss        | 79.4       |
# |    reward             | -0.8773177 |
# |    std                | 1.06       |
# |    value_loss         | 4.4        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 137       |
# |    iterations         | 9500      |
# |    time_elapsed       | 345       |
# |    total_timesteps    | 47500     |
# | train/                |           |
# |    entropy_loss       | -42.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9499      |
# |    policy_loss        | 163       |
# |    reward             | 9.9377775 |
# |    std                | 1.06      |
# |    value_loss         | 98.6      |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 137          |
# |    iterations         | 9600         |
# |    time_elapsed       | 349          |
# |    total_timesteps    | 48000        |
# | train/                |              |
# |    entropy_loss       | -42.6        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 9599         |
# |    policy_loss        | -67.5        |
# |    reward             | -0.082707725 |
# |    std                | 1.06         |
# |    value_loss         | 3.26         |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 137       |
# |    iterations         | 9700      |
# |    time_elapsed       | 353       |
# |    total_timesteps    | 48500     |
# | train/                |           |
# |    entropy_loss       | -42.6     |
# |    explained_variance | 0.00904   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9699      |
# |    policy_loss        | 143       |
# |    reward             | 1.2228097 |
# |    std                | 1.06      |
# |    value_loss         | 14.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 137       |
# |    iterations         | 9800      |
# |    time_elapsed       | 356       |
# |    total_timesteps    | 49000     |
# | train/                |           |
# |    entropy_loss       | -42.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9799      |
# |    policy_loss        | 29.3      |
# |    reward             | 0.9085082 |
# |    std                | 1.05      |
# |    value_loss         | 1.58      |
# -------------------------------------
# day: 1696, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 3798764.79
# total_reward: 2798764.79
# total_cost: 16261.16
# total_trades: 27467
# Sharpe: 1.224
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 137       |
# |    iterations         | 9900      |
# |    time_elapsed       | 360       |
# |    total_timesteps    | 49500     |
# | train/                |           |
# |    entropy_loss       | -42.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9899      |
# |    policy_loss        | 105       |
# |    reward             | 1.6790341 |
# |    std                | 1.05      |
# |    value_loss         | 6.56      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 137        |
# |    iterations         | 10000      |
# |    time_elapsed       | 363        |
# |    total_timesteps    | 50000      |
# | train/                |            |
# |    entropy_loss       | -42.7      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9999       |
# |    policy_loss        | 137        |
# |    reward             | 0.27196515 |
# |    std                | 1.06       |
# |    value_loss         | 10.7       |
# --------------------------------------

# %% [markdown]
# ### Agent 2: DDPG

# %%
agent = DRLAgent(env = env_train)
model_ddpg = agent.get_model("ddpg")

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device
# Logging to results/ddpg

# %%
trained_ddpg = agent.train_model(model=model_ddpg,
                             tb_log_name='ddpg',
                             total_timesteps=50000) if if_using_ddpg else None
# Out:
# -----------------------------------
# | time/              |            |
# |    episodes        | 4          |
# |    fps             | 85         |
# |    time_elapsed    | 79         |
# |    total_timesteps | 6788       |
# | train/             |            |
# |    actor_loss      | 107        |
# |    critic_loss     | 386        |
# |    learning_rate   | 0.001      |
# |    n_updates       | 6687       |
# |    reward          | 0.99182826 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 8          |
# |    fps             | 84         |
# |    time_elapsed    | 159        |
# |    total_timesteps | 13576      |
# | train/             |            |
# |    actor_loss      | 86.8       |
# |    critic_loss     | 20.7       |
# |    learning_rate   | 0.001      |
# |    n_updates       | 13475      |
# |    reward          | 0.99182826 |
# -----------------------------------
# day: 1696, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 2718864.33
# total_reward: 1718864.33
# total_cost: 999.00
# total_trades: 35596
# Sharpe: 0.940
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 12         |
# |    fps             | 84         |
# |    time_elapsed    | 240        |
# |    total_timesteps | 20364      |
# | train/             |            |
# |    actor_loss      | 68.4       |
# |    critic_loss     | 4.28       |
# |    learning_rate   | 0.001      |
# |    n_updates       | 20263      |
# |    reward          | 0.99182826 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 16         |
# |    fps             | 84         |
# |    time_elapsed    | 319        |
# |    total_timesteps | 27152      |
# | train/             |            |
# |    actor_loss      | 43.5       |
# |    critic_loss     | 2.1        |
# |    learning_rate   | 0.001      |
# |    n_updates       | 27051      |
# |    reward          | 0.99182826 |
# -----------------------------------
# day: 1696, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 2718864.33
# total_reward: 1718864.33
# total_cost: 999.00
# total_trades: 35596
# Sharpe: 0.940
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 20         |
# |    fps             | 84         |
# |    time_elapsed    | 399        |
# |    total_timesteps | 33940      |
# | train/             |            |
# |    actor_loss      | 27         |
# |    critic_loss     | 1.39       |
# |    learning_rate   | 0.001      |
# |    n_updates       | 33839      |
# |    reward          | 0.99182826 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 24         |
# |    fps             | 85         |
# |    time_elapsed    | 478        |
# |    total_timesteps | 40728      |
# | train/             |            |
# |    actor_loss      | 15.8       |
# |    critic_loss     | 0.815      |
# |    learning_rate   | 0.001      |
# |    n_updates       | 40627      |
# |    reward          | 0.99182826 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 28         |
# |    fps             | 84         |
# |    time_elapsed    | 559        |
# |    total_timesteps | 47516      |
# | train/             |            |
# |    actor_loss      | 8.34       |
# |    critic_loss     | 0.749      |
# |    learning_rate   | 0.001      |
# |    n_updates       | 47415      |
# |    reward          | 0.99182826 |
# -----------------------------------
# day: 1696, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 2718864.33
# total_reward: 1718864.33
# total_cost: 999.00
# total_trades: 35596
# Sharpe: 0.940
# =================================

# %% [markdown]
# ### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to results/ppo

# %%
trained_ppo = agent.train_model(model=model_ppo,
                             tb_log_name='ppo',
                             total_timesteps=50000) if if_using_ppo else None
# Out:
# ----------------------------------
# | time/              |           |
# |    fps             | 151       |
# |    iterations      | 1         |
# |    time_elapsed    | 13        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | -0.715609 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 2           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013535818 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.0155      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.23        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0214     |
# |    reward               | 2.154393    |
# |    std                  | 1           |
# |    value_loss           | 9.03        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 145         |
# |    iterations           | 3           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012020201 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.0529      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.24        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0202     |
# |    reward               | 0.262894    |
# |    std                  | 1           |
# |    value_loss           | 14.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 4           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016942862 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.0113      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.83        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0224     |
# |    reward               | -1.220449   |
# |    std                  | 1           |
# |    value_loss           | 10.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 5           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.014420249 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0125     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.47        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0245     |
# |    reward               | -0.6175021  |
# |    std                  | 1           |
# |    value_loss           | 11.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 6           |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.016521063 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.00277    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.62        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0225     |
# |    reward               | 0.46431708  |
# |    std                  | 1.01        |
# |    value_loss           | 15.8        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 145        |
# |    iterations           | 7          |
# |    time_elapsed         | 98         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01573423 |
# |    clip_fraction        | 0.187      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.3      |
# |    explained_variance   | 0.0334     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 3.5        |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0249    |
# |    reward               | 0.12740445 |
# |    std                  | 1.01       |
# |    value_loss           | 9.73       |
# ----------------------------------------
# day: 1696, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 2307782.62
# total_reward: 1307782.62
# total_cost: 125295.37
# total_trades: 47352
# Sharpe: 0.957
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 144        |
# |    iterations           | 8          |
# |    time_elapsed         | 113        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.02234152 |
# |    clip_fraction        | 0.251      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.4      |
# |    explained_variance   | -0.027     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 5.47       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0228    |
# |    reward               | -1.9189985 |
# |    std                  | 1.01       |
# |    value_loss           | 11.8       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 144        |
# |    iterations           | 9          |
# |    time_elapsed         | 127        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01867102 |
# |    clip_fraction        | 0.176      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.5      |
# |    explained_variance   | -0.0161    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 4.78       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0264    |
# |    reward               | 3.550912   |
# |    std                  | 1.01       |
# |    value_loss           | 12.3       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 144          |
# |    iterations           | 10           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0178693    |
# |    clip_fraction        | 0.163        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.5        |
# |    explained_variance   | 0.00865      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.27         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.02        |
# |    reward               | -0.047085974 |
# |    std                  | 1.01         |
# |    value_loss           | 15.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 11          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.013869474 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | -0.0135     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.53        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0182     |
# |    reward               | -0.73007494 |
# |    std                  | 1.01        |
# |    value_loss           | 20.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 12          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.016963277 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | -0.0288     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.09        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0165     |
# |    reward               | 1.1105108   |
# |    std                  | 1.01        |
# |    value_loss           | 17          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 13          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.014177566 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | 0.0207      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.99        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0228     |
# |    reward               | -0.81193435 |
# |    std                  | 1.02        |
# |    value_loss           | 14.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 14          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.021295344 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | 0.0141      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.12        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0226     |
# |    reward               | 3.1250374   |
# |    std                  | 1.02        |
# |    value_loss           | 16.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 143          |
# |    iterations           | 15           |
# |    time_elapsed         | 213          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.016292073  |
# |    clip_fraction        | 0.166        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.7        |
# |    explained_variance   | 0.0421       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.06         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0249      |
# |    reward               | -0.024080295 |
# |    std                  | 1.02         |
# |    value_loss           | 13.8         |
# ------------------------------------------
# day: 1696, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 3061347.60
# total_reward: 2061347.60
# total_cost: 120028.68
# total_trades: 46031
# Sharpe: 1.162
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 16          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.022367707 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | 0.0498      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.84        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.019      |
# |    reward               | 0.328566    |
# |    std                  | 1.02        |
# |    value_loss           | 19.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 17          |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.017855655 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | 0.0736      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.12        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0243     |
# |    reward               | -2.2619047  |
# |    std                  | 1.02        |
# |    value_loss           | 18.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 18          |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.020072732 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | -0.0169     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.42        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0187     |
# |    reward               | 0.9343115   |
# |    std                  | 1.02        |
# |    value_loss           | 20.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 19          |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.019652182 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | 0.0729      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.47        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0221     |
# |    reward               | -1.3702499  |
# |    std                  | 1.03        |
# |    value_loss           | 20.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 20          |
# |    time_elapsed         | 284         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.016613686 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.9       |
# |    explained_variance   | 0.0786      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.86        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0227     |
# |    reward               | -1.0035362  |
# |    std                  | 1.03        |
# |    value_loss           | 15.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 21          |
# |    time_elapsed         | 298         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.017800398 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.9       |
# |    explained_variance   | 0.0378      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11          |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0179     |
# |    reward               | 1.2706056   |
# |    std                  | 1.03        |
# |    value_loss           | 19.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 22          |
# |    time_elapsed         | 312         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.021998808 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | 0.0573      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.53        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0193     |
# |    reward               | -0.58515584 |
# |    std                  | 1.03        |
# |    value_loss           | 14.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 23          |
# |    time_elapsed         | 326         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.022964053 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | 0.0559      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.23        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0188     |
# |    reward               | 3.556242    |
# |    std                  | 1.03        |
# |    value_loss           | 17.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 144          |
# |    iterations           | 24           |
# |    time_elapsed         | 341          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0149709955 |
# |    clip_fraction        | 0.137        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42.1        |
# |    explained_variance   | 0.127        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.82         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0179      |
# |    reward               | 0.6167567    |
# |    std                  | 1.04         |
# |    value_loss           | 14.8         |
# ------------------------------------------
# day: 1696, episode: 90
# begin_total_asset: 1000000.00
# end_total_asset: 2459576.77
# total_reward: 1459576.77
# total_cost: 122690.67
# total_trades: 45896
# Sharpe: 0.934
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 25          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.021781258 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | 0.0978      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.31        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0156     |
# |    reward               | 0.8067231   |
# |    std                  | 1.04        |
# |    value_loss           | 16          |
# -----------------------------------------

# %% [markdown]
# ### Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100,
              "buffer_size": 1000000,
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cuda device
# Logging to results/td3

# %%
trained_td3 = agent.train_model(model=model_td3,
                             tb_log_name='td3',
                             total_timesteps=50000) if if_using_td3 else None
# Out:
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 87        |
# |    time_elapsed    | 77        |
# |    total_timesteps | 6788      |
# | train/             |           |
# |    actor_loss      | 97.9      |
# |    critic_loss     | 82        |
# |    learning_rate   | 0.001     |
# |    n_updates       | 6687      |
# |    reward          | 1.3590562 |
# ----------------------------------
# day: 1696, episode: 100
# begin_total_asset: 1000000.00
# end_total_asset: 3101454.22
# total_reward: 2101454.22
# total_cost: 1102.76
# total_trades: 22082
# Sharpe: 0.908
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 88        |
# |    time_elapsed    | 154       |
# |    total_timesteps | 13576     |
# | train/             |           |
# |    actor_loss      | 82        |
# |    critic_loss     | 121       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 13475     |
# |    reward          | 1.3590562 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 88        |
# |    time_elapsed    | 230       |
# |    total_timesteps | 20364     |
# | train/             |           |
# |    actor_loss      | 55.9      |
# |    critic_loss     | 123       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20263     |
# |    reward          | 1.3590562 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 88        |
# |    time_elapsed    | 308       |
# |    total_timesteps | 27152     |
# | train/             |           |
# |    actor_loss      | 49.1      |
# |    critic_loss     | 8.87      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 27051     |
# |    reward          | 1.3590562 |
# ----------------------------------
# day: 1696, episode: 110
# begin_total_asset: 1000000.00
# end_total_asset: 3101454.22
# total_reward: 2101454.22
# total_cost: 1102.76
# total_trades: 22082
# Sharpe: 0.908
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 88        |
# |    time_elapsed    | 384       |
# |    total_timesteps | 33940     |
# | train/             |           |
# |    actor_loss      | 44.6      |
# |    critic_loss     | 7.65      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 33839     |
# |    reward          | 1.3590562 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 88        |
# |    time_elapsed    | 459       |
# |    total_timesteps | 40728     |
# | train/             |           |
# |    actor_loss      | 38.6      |
# |    critic_loss     | 10.9      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 40627     |
# |    reward          | 1.3590562 |
# ----------------------------------
# day: 1696, episode: 120
# begin_total_asset: 1000000.00
# end_total_asset: 3101454.22
# total_reward: 2101454.22
# total_cost: 1102.76
# total_trades: 22082
# Sharpe: 0.908
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 88        |
# |    time_elapsed    | 535       |
# |    total_timesteps | 47516     |
# | train/             |           |
# |    actor_loss      | 37.4      |
# |    critic_loss     | 6.06      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 47415     |
# |    reward          | 1.3590562 |
# ----------------------------------

# %% [markdown]
# ### Agent 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cuda device
# Logging to results/sac

# %%
trained_sac = agent.train_model(model=model_sac,
                             tb_log_name='sac',
                             total_timesteps=50000) if if_using_sac else None
# Out:
# -----------------------------------
# | time/              |            |
# |    episodes        | 4          |
# |    fps             | 60         |
# |    time_elapsed    | 111        |
# |    total_timesteps | 6788       |
# | train/             |            |
# |    actor_loss      | 1.07e+03   |
# |    critic_loss     | 202        |
# |    ent_coef        | 0.178      |
# |    ent_coef_loss   | 178        |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 6687       |
# |    reward          | -2.6073878 |
# -----------------------------------
# day: 1696, episode: 130
# begin_total_asset: 1000000.00
# end_total_asset: 2721481.98
# total_reward: 1721481.98
# total_cost: 63836.35
# total_trades: 42103
# Sharpe: 1.013
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 60        |
# |    time_elapsed    | 225       |
# |    total_timesteps | 13576     |
# | train/             |           |
# |    actor_loss      | 805       |
# |    critic_loss     | 369       |
# |    ent_coef        | 0.144     |
# |    ent_coef_loss   | -88.5     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 13475     |
# |    reward          | 2.2496607 |
# ----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 12         |
# |    fps             | 60         |
# |    time_elapsed    | 339        |
# |    total_timesteps | 20364      |
# | train/             |            |
# |    actor_loss      | 478        |
# |    critic_loss     | 94.1       |
# |    ent_coef        | 0.0731     |
# |    ent_coef_loss   | -118       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 20263      |
# |    reward          | 0.32523844 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 16         |
# |    fps             | 59         |
# |    time_elapsed    | 453        |
# |    total_timesteps | 27152      |
# | train/             |            |
# |    actor_loss      | 302        |
# |    critic_loss     | 51.1       |
# |    ent_coef        | 0.0373     |
# |    ent_coef_loss   | -138       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 27051      |
# |    reward          | 0.87562245 |
# -----------------------------------
# day: 1696, episode: 140
# begin_total_asset: 1000000.00
# end_total_asset: 2490152.00
# total_reward: 1490152.00
# total_cost: 6668.76
# total_trades: 30001
# Sharpe: 0.874
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 59        |
# |    time_elapsed    | 567       |
# |    total_timesteps | 33940     |
# | train/             |           |
# |    actor_loss      | 219       |
# |    critic_loss     | 13.6      |
# |    ent_coef        | 0.0191    |
# |    ent_coef_loss   | -154      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 33839     |
# |    reward          | 1.5739231 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 59        |
# |    time_elapsed    | 683       |
# |    total_timesteps | 40728     |
# | train/             |           |
# |    actor_loss      | 145       |
# |    critic_loss     | 5.76      |
# |    ent_coef        | 0.00978   |
# |    ent_coef_loss   | -158      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 40627     |
# |    reward          | 1.8501223 |
# ----------------------------------
# day: 1696, episode: 150
# begin_total_asset: 1000000.00
# end_total_asset: 2650763.17
# total_reward: 1650763.17
# total_cost: 2835.06
# total_trades: 27393
# Sharpe: 0.978
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 59        |
# |    time_elapsed    | 797       |
# |    total_timesteps | 47516     |
# | train/             |           |
# |    actor_loss      | 101       |
# |    critic_loss     | 5.72      |
# |    ent_coef        | 0.00505   |
# |    ent_coef_loss   | -151      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 47415     |
# |    reward          | 2.0918372 |
# ----------------------------------

# %% [markdown]
# ## In-sample Performance
#
# Assume that the initial capital is $1,000,000.

# %% [markdown]
# ### Trading (Out-of-sample Performance)
#
# We update periodically in order to take full advantage of the data, e.g., retrain quarterly, monthly or weekly. We also tune the parameters along the way, in this notebook we use the in-sample data from 2009-01 to 2020-07 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
e_trade_gym = StockTradingEnv(df = trade,
                              # turbulence_threshold = 70,
                              # risk_indicator_col='vix',
                              **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %%
trade.head()
# Out:
#          date        open        high         low       close     volume  \
# 0  2015-10-01   27.267500   27.405001   26.827499   24.802267  255716400
# 0  2015-10-01  138.550003  140.639999  136.600006  109.398338    4675900
# 0  2015-10-01   74.160004   74.599998   73.209999   64.806305    4741100
# 0  2015-10-01  131.320007  131.789993  128.979996  116.415619    2878400
# 0  2015-10-01   65.629997   66.099998   63.610001   51.167412    7933000
#
#     tic  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  AAPL    3 -0.187381   26.637193   24.476343  43.898527  -80.897496
# 0  AMGN    3 -4.083573  124.956575  103.814142  41.908513 -129.755260
# 0   AXP    3 -0.669695   68.030771   63.972712  44.069330 -102.606444
# 0    BA    3 -1.450074  123.558008  113.339465  44.012203  -40.081343
# 0   CAT    3 -2.405400   62.577814   49.582028  33.910569 -160.859099
#
#        dx_30  close_30_sma  close_60_sma  turbulence
# 0  42.094442     25.291612     26.325272   36.884173
# 0  42.285097    115.947318    122.724404   36.884173
# 0  12.390658     66.184462     67.390719   36.884173
# 0  22.520522    117.726766    123.058700   36.884173
# 0  48.369829     57.231896     60.103397   36.884173

# %%
trained_moedl = trained_a2c
df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
    model=trained_moedl,
    environment = e_trade_gym)
# Out:
# hit end!

# %%
trained_moedl = trained_ddpg
df_account_value_ddpg, df_actions_ddpg = DRLAgent.DRL_prediction(
    model=trained_moedl,
    environment = e_trade_gym)
# Out:
# hit end!

# %%
trained_moedl = trained_ppo
df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_moedl,
    environment = e_trade_gym)
# Out:
# hit end!

# %%
trained_moedl = trained_td3
df_account_value_td3, df_actions_td3 = DRLAgent.DRL_prediction(
    model=trained_moedl,
    environment = e_trade_gym)
# Out:
# hit end!

# %%
trained_moedl = trained_sac
df_account_value_sac, df_actions_sac = DRLAgent.DRL_prediction(
    model=trained_moedl,
    environment = e_trade_gym)
# Out:
# hit end!

# %%
df_account_value_a2c.shape
# Out:
# (1323, 2)

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtesting Results
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
df_result_a2c = df_account_value_a2c.set_index(df_account_value_a2c.columns[0])
df_result_ddpg = df_account_value_ddpg.set_index(df_account_value_ddpg.columns[0])
df_result_td3 = df_account_value_td3.set_index(df_account_value_td3.columns[0])
df_result_ppo = df_account_value_ppo.set_index(df_account_value_ppo.columns[0])
df_result_sac = df_account_value_sac.set_index(df_account_value_sac.columns[0])
df_account_value_a2c.to_csv("df_account_value_a2c.csv")
#baseline stats
print("==============Get Baseline Stats===========")
df_dji_ = get_baseline(
        ticker="^DJI",
        start = TRADE_START_DATE,
        end = TRADE_END_DATE)
stats = backtest_stats(df_dji_, value_col_name = 'close')
df_dji = pd.DataFrame()
df_dji['date'] = df_account_value_a2c['date']
df_dji['account_value'] = df_dji_['close'] / df_dji_['close'][0] * env_kwargs["initial_amount"]
df_dji.to_csv("df_dji.csv")
df_dji = df_dji.set_index(df_dji.columns[0])
df_dji.to_csv("df_dji+.csv")

result = pd.merge(df_result_a2c, df_result_ddpg, left_index=True, right_index=True, suffixes=('_a2c', '_ddpg'))
result = pd.merge(result, df_result_td3, left_index=True, right_index=True, suffixes=('', '_td3'))
result = pd.merge(result, df_result_ppo, left_index=True, right_index=True, suffixes=('', '_ppo'))
result = pd.merge(result, df_result_sac, left_index=True, right_index=True, suffixes=('', '_sac'))
result.columns = ['a2c', 'ddpg', 'td3', 'ppo', 'sac']

print("result: ", result)
result.to_csv("result.csv")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ==============Get Baseline Stats===========
# Shape of DataFrame:  (1323, 8)
# Annual return          0.127876
# Cumulative returns     0.880928
# Annual volatility      0.199160
# Sharpe ratio           0.705053
# Calmar ratio           0.344808
# Stability              0.822474
# Max drawdown          -0.370862
# Omega ratio            1.165017
# Sortino ratio          0.972446
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.894816
# Daily value at risk   -0.024535
# dtype: float64
# result:                       a2c          ddpg           td3           ppo  \
# date
# 2015-10-01  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# 2015-10-02  1.000643e+06  1.001617e+06  1.000949e+06  1.000087e+06
# 2015-10-05  1.003554e+06  1.006476e+06  1.004627e+06  1.000483e+06
# 2015-10-06  1.002534e+06  1.005192e+06  1.003895e+06  1.000444e+06
# 2015-10-07  1.004489e+06  1.011005e+06  1.006671e+06  1.000874e+06
# ...                  ...           ...           ...           ...
# 2020-12-24  2.269832e+06  2.037453e+06  2.350073e+06  1.862077e+06
# 2020-12-28  2.293169e+06  2.052159e+06  2.366880e+06  1.878876e+06
# 2020-12-29  2.297796e+06  2.045926e+06  2.365042e+06  1.884864e+06
# 2020-12-30  2.304499e+06  2.049492e+06  2.370483e+06  1.891796e+06
# 2020-12-31  2.321169e+06  2.063401e+06  2.392587e+06  1.901971e+06
#
#                      sac
# date
# 2015-10-01  1.000000e+06
# 2015-10-02  1.000835e+06
# 2015-10-05  1.002993e+06
# 2015-10-06  1.001853e+06
# 2015-10-07  1.005232e+06
# ...                  ...
# 2020-12-24  2.001196e+06
# 2020-12-28  2.017980e+06
# 2020-12-29  2.017449e+06
# 2020-12-30  2.024945e+06
# 2020-12-31  2.036948e+06
#
# [1323 rows x 5 columns]

# %%
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot();

# %%
from google.colab import files
result.to_csv('result.csv')
files.download('result.csv')

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/Colab Notebooks/Comp579_Project/RerunNotebook_2018')
# Out:
# Mounted at /content/drive

# %%
# Combine all results

single_agents_results = result
ensemble_results = pd.read_csv("notebook_ensemble_result.csv")

# %%
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
ensemble_results.plot();

# %%
min_date = ensemble_results.date.unique()[0]
max_date = ensemble_results.date.unique()[-1]

single_agents_results = single_agents_results.reset_index()
selected_data_DRLagents = single_agents_results[(single_agents_results.date >= min_date)&(single_agents_results.date <= max_date)]
selected_data_DRLagents.reset_index(drop=True, inplace=True)
selected_data_DRLagents

new_data_DRLagents = pd.DataFrame()
new_data_DRLagents['date'] = selected_data_DRLagents['date']

for method in ['a2c', 'ddpg', 'td3', 'ppo', 'sac']:
    method_return = selected_data_DRLagents[method].pct_change()
    cumulative_returns = (1 + method_return).cumprod()
    cumulative_returns[0] = 1
    new_data_DRLagents[method] = cumulative_returns * 1.000000e+06

# %%
all_values = pd.concat([new_data_DRLagents, ensemble_results[['ensemble', 'dji']]], axis=1)
all_values
# Out:
#             date           a2c          ddpg           td3           ppo  \
# 0     2016-01-04  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# 1     2016-01-05  9.991851e+05  9.994227e+05  1.000429e+06  9.976291e+05
# 2     2016-01-06  9.873017e+05  9.855822e+05  9.858230e+05  9.866368e+05
# 3     2016-01-07  9.629188e+05  9.615708e+05  9.582406e+05  9.669807e+05
# 4     2016-01-08  9.500326e+05  9.516989e+05  9.470857e+05  9.602289e+05
# ...          ...           ...           ...           ...           ...
# 1192  2020-09-28  1.986850e+06  1.778330e+06  2.041846e+06  1.740679e+06
# 1193  2020-09-29  1.981618e+06  1.771321e+06  2.034943e+06  1.734054e+06
# 1194  2020-09-30  2.011323e+06  1.793196e+06  2.063020e+06  1.753603e+06
# 1195  2020-10-01  2.022596e+06  1.792758e+06  2.069674e+06  1.754541e+06
# 1196  2020-10-02  2.012161e+06  1.789254e+06  2.069202e+06  1.724279e+06
#
#                sac      ensemble           dji
# 0     1.000000e+06  1.000000e+06  1.000000e+06
# 1     1.002766e+06  9.999706e+05  1.000567e+06
# 2     9.916442e+05  9.984697e+05  9.858633e+05
# 3     9.671266e+05  9.959340e+05  9.629808e+05
# 4     9.550435e+05  9.944832e+05  9.532047e+05
# ...            ...           ...           ...
# 1192  1.716552e+06  1.703000e+06  1.608500e+06
# 1193  1.708668e+06  1.695198e+06  1.600837e+06
# 1194  1.727736e+06  1.718356e+06  1.620024e+06
# 1195  1.731941e+06  1.719019e+06  1.622077e+06
# 1196  1.726917e+06  1.705028e+06           NaN
#
# [1197 rows x 8 columns]

# %%
all_values1 = all_values[(all_values.date >= '2016-01-03')&(all_values.date <= '2020-05-08')]
all_values1
# Out:
#             date           a2c          ddpg           td3           ppo  \
# 0     2016-01-04  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# 1     2016-01-05  9.991851e+05  9.994227e+05  1.000429e+06  9.976291e+05
# 2     2016-01-06  9.873017e+05  9.855822e+05  9.858230e+05  9.866368e+05
# 3     2016-01-07  9.629188e+05  9.615708e+05  9.582406e+05  9.669807e+05
# 4     2016-01-08  9.500326e+05  9.516989e+05  9.470857e+05  9.602289e+05
# ...          ...           ...           ...           ...           ...
# 1090  2020-05-04  1.759011e+06  1.512589e+06  1.730894e+06  1.548974e+06
# 1091  2020-05-05  1.766648e+06  1.520611e+06  1.739255e+06  1.555227e+06
# 1092  2020-05-06  1.746242e+06  1.504881e+06  1.719182e+06  1.544597e+06
# 1093  2020-05-07  1.764693e+06  1.518196e+06  1.740800e+06  1.553065e+06
# 1094  2020-05-08  1.793963e+06  1.548433e+06  1.773976e+06  1.578922e+06
#
#                sac      ensemble           dji
# 0     1.000000e+06  1.000000e+06  1.000000e+06
# 1     1.002766e+06  9.999706e+05  1.000567e+06
# 2     9.916442e+05  9.984697e+05  9.858633e+05
# 3     9.671266e+05  9.959340e+05  9.629808e+05
# 4     9.550435e+05  9.944832e+05  9.532047e+05
# ...            ...           ...           ...
# 1090  1.527273e+06  1.522347e+06  1.384911e+06
# 1091  1.533433e+06  1.538813e+06  1.392686e+06
# 1092  1.517334e+06  1.526147e+06  1.379948e+06
# 1093  1.527056e+06  1.526662e+06  1.392266e+06
# 1094  1.553423e+06  1.549307e+06  1.418824e+06
#
# [1095 rows x 8 columns]

# %%
all_values1.to_csv('all_values_notebook.csv')
files.download('all_values_notebook.csv')

# %%
all_values1.set_index('date', inplace=True)
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
all_values1.plot(grid=True);
